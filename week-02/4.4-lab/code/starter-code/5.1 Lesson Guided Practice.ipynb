# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
dfBar = pd.DataFrame(np.random.randn(10, 4), columns=['a', 'b', 'c', 'd'])
dfBar
# Out:
#           a         b         c         d
# 0  0.878386 -0.016239  1.048440 -0.075514
# 1 -0.158804  0.597318  0.107445 -1.544109
# 2  0.505989 -0.670303 -1.570378  0.060222
# 3  1.653646 -0.811443 -0.652495 -0.745693
# 4 -0.630561 -0.682464 -1.561275  1.162810
# 5 -1.026881 -0.228947 -0.489964 -0.778369
# 6  0.627575  0.029002 -1.785867  0.925209
# 7 -0.387024 -0.122601  0.869857 -0.746507
# 8  0.343215  0.549351 -1.174969 -0.854311
# 9  1.194219  0.860549 -1.372725 -0.918629

# %%
dfBar.plot(kind="bar")
plt.show()

# %%
dfBar.plot(kind="bar", stacked=True)
plt.show()

# %%
dfBar.plot(kind="barh", stacked=True)
plt.show()

# %%
dfScat = pd.DataFrame(np.random.randn(50, 4), columns=['a', 'b', 'c', 'd'])
dfScat
# Out:
#            a         b         c         d
# 0  -0.505446 -0.573475  0.307758  1.455235
# 1   0.755541  0.140751  0.288003  0.567593
# 2   0.230115  0.175902 -1.363989 -1.040475
# 3   0.161798  0.791799 -0.296979  0.456474
# 4   0.538100 -0.344424  1.374378  1.571301
# 5  -1.653330 -0.680353  0.541141 -0.016348
# 6   1.516561 -0.743556  0.791941 -0.684315
# 7   0.084413 -0.050266  1.473378 -1.063784
# 8  -0.817338 -0.120298  0.161250 -1.832030
# 9   0.491096 -0.521399  0.859197 -0.283051
# 10 -0.443811 -1.003122  0.069821  1.740514
# 11  0.597098  1.326667  0.060281 -0.245860
# 12  1.950865 -0.866734 -0.006974  0.739600
# 13 -1.405296  0.900242  2.208722  1.008824
# 14  1.451255 -1.202109 -0.563732 -0.115546
# 15 -0.510783 -1.455683  0.674455  1.619056
# 16  0.485744  0.468975  1.217967  0.348459
# 17 -2.162905 -0.442017  0.320326 -0.588904
# 18 -0.156718 -0.416090  0.848340  1.637999
# 19 -1.340259 -0.507580  1.285017 -0.247708
# 20  0.995392 -0.883570  1.088860  1.338460
# 21  0.211437 -1.009490 -0.576459 -0.692660
# 22  1.236830 -2.067608 -1.184537 -1.898960
# 23  0.835245 -2.405312 -0.271851  0.359393
# 24 -1.199227  0.964694  2.624681 -0.208303
# 25 -0.937116  1.018786  0.445664 -1.384875
# 26 -0.605829  0.566006  0.944989  0.589024
# 27 -0.110840 -0.591086 -0.774842 -0.744793
# 28  0.183255  0.538512 -1.000986  1.713818
# 29  0.650852  0.301527  1.192338 -1.330278
# 30  1.788082 -2.192380 -0.218227  2.061794
# 31 -2.064921  0.132335 -0.749176 -0.546404
# 32 -0.308216  0.112323 -1.101067 -0.796230
# 33 -1.390088  0.668682  1.528954 -1.162208
# 34 -1.690515  0.321736  0.223167  0.877897
# 35  0.676634 -0.457489  0.043856  0.138074
# 36  0.352970  1.790541 -1.294824  0.863266
# 37 -0.493299  0.767127  0.800611 -0.673023
# 38 -0.144832  1.806549  0.981224 -0.771616
# 39  0.243772  0.881325  2.466975 -0.112465
# 40  0.275168  0.208288 -1.810033  0.400068
# 41 -0.675428 -1.637135  0.954113 -0.670622
# 42  0.196091  0.194730 -0.279613 -0.348555
# 43 -1.876285  0.087469 -1.411877 -2.204760
# 44  0.386904  1.422363 -0.304212 -0.345065
# 45  0.769349  1.457073  1.116070 -0.952341
# 46  0.370838 -0.327648  1.684777 -0.940796
# 47 -0.934795  0.217653  0.689758  1.650109
# 48 -1.547595  2.019669 -1.206306  1.535032
# 49  0.412750  1.736914 -0.247991  0.082798

# %%
ax = dfScat.plot(kind ="scatter", x="a",y="b", color ="r", label="Group 1");
dfScat.plot.scatter(x="c",y="d", color ="Green", label ="Group 2", ax=ax);
#rename labels below, otherwise will use axes names of the last plot
ax.set_xlabel("a,c")
ax.set_ylabel("b,d")
plt.show()

# %%
data = {'date': ['2014-05-01 18:47:05.069722', '2014-05-01 18:47:05.119994',
'2014-05-02 18:47:05.178768', '2014-05-02 18:47:05.230071',
'2014-05-02 18:47:05.230071', '2014-05-02 18:47:05.280592',
'2014-05-03 18:47:05.332662', '2014-05-03 18:47:05.385109',
'2014-05-04 18:47:05.436523', '2014-05-10 18:47:05.486877'],
        'battle_deaths': [34, 25, 26, 15, 15, 14, 26, 25, 62, 41]}
df = pd.DataFrame(data, columns = ['date', 'battle_deaths'])
print(df)
# Out:
#                          date  battle_deaths
# 0  2014-05-01 18:47:05.069722             34
# 1  2014-05-01 18:47:05.119994             25
# 2  2014-05-02 18:47:05.178768             26
# 3  2014-05-02 18:47:05.230071             15
# 4  2014-05-02 18:47:05.230071             15
# 5  2014-05-02 18:47:05.280592             14
# 6  2014-05-03 18:47:05.332662             26
# 7  2014-05-03 18:47:05.385109             25
# 8  2014-05-04 18:47:05.436523             62
# 9  2014-05-10 18:47:05.486877             41

# %%
#dot notation is ok
#df['date'] = pd.to_datetime(df['date'])
df.date = pd.to_datetime(df['date'])
df.dtypes
# Out:
# date             datetime64[ns]
# battle_deaths             int64
# dtype: object

# %%
df.index = df['date']
del df['date']
df
# Out:
#                             battle_deaths
# date
# 2014-05-01 18:47:05.069722             34
# 2014-05-01 18:47:05.119994             25
# 2014-05-02 18:47:05.178768             26
# 2014-05-02 18:47:05.230071             15
# 2014-05-02 18:47:05.230071             15
# 2014-05-02 18:47:05.280592             14
# 2014-05-03 18:47:05.332662             26
# 2014-05-03 18:47:05.385109             25
# 2014-05-04 18:47:05.436523             62
# 2014-05-10 18:47:05.486877             41

# %%
#df.resample('D', how='sum').plot()
df.resample('D').sum().plot()
plt.show()

# %%
df.resample('T').sum().plot()
plt.show()
